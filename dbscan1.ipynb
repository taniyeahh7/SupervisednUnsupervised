# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
blobs=pd.read_csv('./datasets/cluster-blobs.csv')

# %%
blobs.head()
# Out:
#          X1        X2
# 0  4.645333  6.822294
# 1  4.784032  6.422883
# 2 -5.851786  5.774331
# 3 -7.459592  6.456415
# 4  4.918911  6.961479

# %%
sns.scatterplot(data=blobs,x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
moons=pd.read_csv('./datasets/cluster-moons.csv')

# %%
moons.head()
# Out:
#          X1        X2
# 0  0.674362 -0.444625
# 1  1.547129 -0.239796
# 2  1.601930 -0.230792
# 3  0.014563  0.449752
# 4  1.503476 -0.389164

# %%
sns.scatterplot(x='X1',y='X2',data=moons)
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %% [markdown]
# the proximity of the end points of the moons must be noted

# %%
circles=pd.read_csv('./datasets/cluster-circles.csv')

# %%
circles.head()
# Out:
#          X1        X2
# 0 -0.348677  0.010157
# 1 -0.176587 -0.954283
# 2  0.301703 -0.113045
# 3 -0.782889 -0.719468
# 4 -0.733280 -0.757354

# %%
sns.scatterplot(x='X1',y='X2',data=circles)
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model,data):
    labels=model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')

# %% [markdown]
# set1 for colour choices to make nice visually

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3)

# %%
display_categories(model,blobs)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df=pd.read_csv('./datasets/trial5.csv')

# %%
model=KMeans(n_clusters=2)

# %%
display_categories(model,moons)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
display_categories(model,circles)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# based on distance

# %%
from sklearn.cluster import DBSCAN

# %%
help(DBSCAN)
# Out:
# Help on class DBSCAN in module sklearn.cluster._dbscan:
#
# class DBSCAN(sklearn.base.ClusterMixin, sklearn.base.BaseEstimator)
#  |  DBSCAN(eps=0.5, *, min_samples=5, metric='euclidean', metric_params=None, algorithm='auto', leaf_size=30, p=None, n_jobs=None)
#  |
#  |  Perform DBSCAN clustering from vector array or distance matrix.
#  |
#  |  DBSCAN - Density-Based Spatial Clustering of Applications with Noise.
#  |  Finds core samples of high density and expands clusters from them.
#  |  Good for data which contains clusters of similar density.
#  |
#  |  Read more in the :ref:`User Guide <dbscan>`.
#  |
#  |  Parameters
#  |  ----------
#  |  eps : float, default=0.5
#  |      The maximum distance between two samples for one to be considered
#  |      as in the neighborhood of the other. This is not a maximum bound
#  |      on the distances of points within a cluster. This is the most
#  |      important DBSCAN parameter to choose appropriately for your data set
# ...

# %%
model_dbscan=DBSCAN()

# %%
display_categories(model_dbscan,blobs)

# %%
display_categories(model_dbscan,df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 display_categories(model_dbscan,df)
#
# Cell In[29], line 3, in display_categories(model, data)
#       1 def display_categories(model,data):#helper function taht takes in amodel and decide hypermparams before hand?
#       2     labels=model.fit_predict(data)
# ----> 3     sns.scatterplot(data=data,x='X1',y='X2',palette='Set1',hue=labels)
#
# File c:\ProgramData\anaconda3\lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# ...

# %% [markdown]
# DBSCAN HAS A SPECIAL CATEGORY OF OUTLIER= -1 based off the hyperparameters =epsilon and number of points
# itself determines 3 cluster

# %%
model=DBSCAN(eps=0.15)#modified the value of eps
display_categories(model,moons)

# %%
display_categories(model,circles)

# %% [markdown]
# by techniques can find the best value of epsilon and minimum number of points

# %%
two_blobs=pd.read_csv('./datasets/cluster-two-blobs.csv')

# %%
two_blobs_outliers=pd.read_csv('./datasets/cluster-two-blobs-outliers.csv')

# %%
sns.scatterplot(data=two_blobs_outliers,x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model,data):#helper function taht takes in amodel and decide hypermparams before hand?
    labels=model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',palette='Set1',hue=labels)

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan=DBSCAN()

# %%
help(dbscan)
# Out:
# Help on DBSCAN in module sklearn.cluster._dbscan object:
#
# class DBSCAN(sklearn.base.ClusterMixin, sklearn.base.BaseEstimator)
#  |  DBSCAN(eps=0.5, *, min_samples=5, metric='euclidean', metric_params=None, algorithm='auto', leaf_size=30, p=None, n_jobs=None)
#  |
#  |  Perform DBSCAN clustering from vector array or distance matrix.
#  |
#  |  DBSCAN - Density-Based Spatial Clustering of Applications with Noise.
#  |  Finds core samples of high density and expands clusters from them.
#  |  Good for data which contains clusters of similar density.
#  |
#  |  Read more in the :ref:`User Guide <dbscan>`.
#  |
#  |  Parameters
#  |  ----------
#  |  eps : float, default=0.5
#  |      The maximum distance between two samples for one to be considered
#  |      as in the neighborhood of the other. This is not a maximum bound
#  |      on the distances of points within a cluster. This is the most
#  |      important DBSCAN parameter to choose appropriately for your data set
# ...

# %%
display_categories(dbscan,two_blobs)

# %% [markdown]
# marks are outlier points neither border nor core points

# %%
display_categories(dbscan,two_blobs_outliers)

# %%
dbscan=DBSCAN(eps=0.001)
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# saying everything is an outlier cuz marked as -1

# %% [markdown]
# saying everything as

# %%
dbscan=DBSCAN(eps=10)
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# saything everything is an outlier

# %%
dbscan=DBSCAN(eps=1)
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# 3 outliers

# %%
np.sum(dbscan.labels_==-1)#can measure how many outliers are
# Out:
# 3

# %% [markdown]
# very useful for number of outliers and how many outliers should be there

# %%
10*np.sum(dbscan.labels_==-1)/len(dbscan.labels_)#total percent of points classified as outliers
# Out:
# 0.02991026919242273

# %%
len(dbscan.labels_)
# Out:
# 1003

# %%
len(np.unique(dbscan.labels_))
# Out:
# 3

# %%
outlier_percent=[]
number_of_outlier=[]

for eps in np.linspace(0.001,10,100):#want LINEAR SPACE
    dbscan=DBSCAN(eps=eps)
    dbscan.fit(two_blobs_outliers)
    
    #total number of outliers found
    number_of_outlier.append(np.sum(dbscan.labels_==-1))
    
    #percent of points classified as outliers
    perc_outliers=100*np.sum(dbscan.labels_==-1)/len(dbscan.labels_)
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.linspace(0.001,10,100),y=number_of_outlier)
plt.xlim(0,2)#to check where change occurs
# Out:
# (0.0, 2.0)

# %%
outlier_percent=[]
number_of_outlier=[]

for eps in np.linspace(0.001,7,100):#want LINEAR SPACE
    dbscan=DBSCAN(eps=eps)
    dbscan.fit(two_blobs_outliers)
    
    #total number of outliers found
    number_of_outlier.append(np.sum(dbscan.labels_==-1))
    
    #percent of points classified as outliers
    perc_outliers=100*np.sum(dbscan.labels_==-1)/len(dbscan.labels_)
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.linspace(0.001,7,100),y=number_of_outlier)
plt.xlim(0,2)#to check where change occurs
plt.ylim(0,10)
plt.ylabel('Percent of Points classfied as outliers')
plt.hlines(y=3,xmin=0,xmax=2,color='red')#expecting 3 outliers

# %% [markdown]
# something wrong , but still points scome thru this only where 0.75 epsilon makes the the right number of outliers

# %% [markdown]
# looks smoother

# %% [markdown]
# interested in inflection points
# at 2,4,5,6,7,8,9
# very large epsilon

# %%
dbscan=DBSCAN(eps=0.75)
display_categories(dbscan,two_blobs_outliers)

# %%
outlier_percent=[]
number_of_outlier=[]

for eps in np.linspace(0.001,1,100):#want LINEAR SPACE
    dbscan=DBSCAN(eps=eps)
    dbscan.fit(two_blobs_outliers)
    
    #total number of outliers found
    number_of_outlier.append(np.sum(dbscan.labels_==-1))
    
    #percent of points classified as outliers
    perc_outliers=100*np.sum(dbscan.labels_==-1)/len(dbscan.labels_)
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.linspace(0.001,1,100),y=number_of_outlier)
plt.xlim(0,2)#to check where change occurs
plt.ylim(0,10)
plt.ylabel('Percent of Points classfied as outliers')
plt.hlines(y=3,xmin=0,xmax=2,color='red')#expecting 3 outliers

# %% [markdown]
# is correct

# %%
# sns.lineplot(x=np.linspace(0.001,7,200),y=outlier_percent)
# plt.xlim(0,2)
# plt.ylim(0,10)
# plt.hlines(y=1,xmin=0,xmax=2,color='red')
# plt.ylabel('Percent of points classified as outliers')
#DOES NOT WORK FOR SOME REASON

# %% [markdown]
# LOOKING FOR INFLECTION POINTS THATS IT FOR NUMBER OF MINIMUM POINTS ALSO
# TAKE THEM AS UNIQUE CLUSTERS ALSO

# %% [markdown]
# nOTE: NP.ARANGE GIVES IN A RANGE OF WHOLE NUMBERS WHILE
#       NP.LINSPACE GIVE DECIMALS ALSO
#       CANT HAVE DECIMALS VALUES AS NUMBER OF POINTS

# %%
outlier_percent=[]
number_of_outliers=[]

for n in np.arange(1,100):
    dbscan=DBSCAN(min_samples=n)
    dbscan.fit(two_blobs_outliers)
    number_of_outliers.append(np.sum(dbscan.labels_==-1))
    perc_outliers=100*np.sum(dbscan.labels_==-1)/len(dbscan.labels_)
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.arange(1,100),y=outlier_percent)
plt.xlabel('Min number of samples')
plt.ylabel('percent of points classified as an outlier')
# Out:
# Text(0, 0.5, 'percent of points classified as an outlier')

# %% [markdown]
# as increasing threshold of min number of points to be considered in neighbourhood the more and more considered into clusters

# %%
dbscan=DBSCAN(min_samples=1,eps=0.75)
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# (2 * dimension of data) is a good value for value of minimum number of points

# %%
num_dim=two_blobs_outliers.shape[1]
dbscan=DBSCAN(min_samples=2*num_dim,eps=0.75)
display_categories(dbscan,two_blobs_outliers)
