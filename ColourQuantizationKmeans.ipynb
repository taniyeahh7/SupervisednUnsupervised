# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# matplot lib also has an image processing package in it
# can read image and convert them into numpy and panda arrays

# %%
import matplotlib.image as mpimg

# %%
image_as_array=mpimg.imread('./palm-trees.jpg')
image_as_array
#25 89 127 red green blue
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
# ...

# %%
image_as_array.shape#height,width and channels
# Out:
# (1401, 934, 3)

# %%
#plt.figure(dpi=200)
plt.imshow(image_as_array)#is blurry#works only for arrays and not png or jpg

# %% [markdown]
# need to make
# h,w,c->2d=(h*w,c)

# %%
(h,w,c)=image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array2d=image_as_array.reshape(h*w,c)#flattening out essentially

# %%
image_as_array2d#here numbre of brackets is different
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
len(image_as_array.shape)
# Out:
# 3

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=9)#want to avg out to 6 colours

# %%
labels=model.fit_predict(image_as_array2d)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# Note: kmeans can only process 2d array

# %%
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0])

# %% [markdown]
# could want just a sample also but here we got out of it okay

# %%
rgb_codes=model.cluster_centers_.round(0).astype(int)
rgb_codes
# Out:
# array([[  3,   2,   3],
#        [137, 144, 145],
#        [208, 154,  88],
#        [ 56,  96, 128],
#        [ 91, 124, 146],
#        [228, 135,  36],
#        [ 57,  55,  58],
#        [176, 155, 127],
#        [151,  96,  58]])

# %% [markdown]
# need to assign rgb codes

# %%
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0])

# %% [markdown]
# starting points in kmeans for different people is different
# VERY imp
# here basically 3,3,4 has been assigned the label 2

# %%
rgb_codes[labels]#gives averaged  out rgb values
# Out:
# array([[ 56,  96, 128],
#        [ 56,  96, 128],
#        [ 56,  96, 128],
#        ...,
#        [  3,   2,   3],
#        [  3,   2,   3],
#        [  3,   2,   3]])

# %%
image_as_array2d#reassigning the values to go the centers
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
quantized_timage=np.reshape(rgb_codes[labels],(h,w,c))#reshaping it so that can be displayed
quantized_timage
# Out:
# array([[[ 56,  96, 128],
#         [ 56,  96, 128],
#         [ 56,  96, 128],
#         ...,
#         [ 57,  55,  58],
#         [ 56,  96, 128],
#         [ 56,  96, 128]],
#
#        [[ 56,  96, 128],
#         [ 56,  96, 128],
#         [ 56,  96, 128],
#         ...,
#         [ 56,  96, 128],
#         [ 56,  96, 128],
#         [ 56,  96, 128]],
#
#        [[ 56,  96, 128],
#         [ 56,  96, 128],
#         [ 56,  96, 128],
#         ...,
#         [ 56,  96, 128],
#         [ 56,  96, 128],
#         [ 56,  96, 128]],
#
#        ...,
#
#        [[  3,   2,   3],
#         [  3,   2,   3],
#         [  3,   2,   3],
#         ...,
#         [  3,   2,   3],
#         [  3,   2,   3],
#         [  3,   2,   3]],
#
#        [[  3,   2,   3],
#         [  3,   2,   3],
#         [  3,   2,   3],
#         ...,
#         [  3,   2,   3],
#         [  3,   2,   3],
#         [  3,   2,   3]],
#
#        [[  3,   2,   3],
#         [  3,   2,   3],
#         [  3,   2,   3],
# ...

# %%
plt.imshow(quantized_timage)

# %% [markdown]
# gives essentially just the 6 colours

# %% [markdown]
# EXERCISEEEE
# ALSO MAKE A GEOGRAPHICAL MAP PLOTLYYY

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('./CIA-Country-Facts.csv')
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.histplot(data=df[df['Population']<200000000],x='Population')
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(data=df,y='GDP ($ per capita)',x='Region')#black one is thstd deviation and its us that is creating that skewness
plt.xticks(rotation=90);

# %%
scplt=sns.scatterplot(y='Phones (per 1000)',x='GDP ($ per capita)',data=df,hue='Region')
plt.legend(loc=(1.05,0.5))

# %% [markdown]
# insight=more gdp more number of phones
# will try to get the outliers

# %%
df[df['Phones (per 1000)']>900]
# Out:
#     Country                               Region  Population  Area (sq. mi.)  \
# 138  Monaco  WESTERN EUROPE                            32543               2
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 138                     16271.5                         205.0           7.75
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 138                                5.43             27000.0          99.0
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)   Climate  Birthrate  \
# 138             1035.6         0.0        0.0      100.0  1.997608       9.19
#
#      Deathrate  Agriculture  Industry  Service
# 138      12.91         0.17       NaN      NaN

# %%
scplt2=sns.scatterplot(x='GDP ($ per capita)',y='Literacy (%)',data=df,hue='Region')

# %% [markdown]
# gathered that in case of europe atleast higher gdp higher literacythreshold on gdp per capita
# even at low gdp per capita good literacy rates

# %% [markdown]
# creating a heatmap of correlations of the columns in the dataset

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
# C:\Users\Taniya\AppData\Local\Temp\ipykernel_45508\363827394.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=df.corr()
#                                     Population  Area (sq. mi.)  \
# Population                            1.000000        0.469985
# Area (sq. mi.)                        0.469985        1.000000
# Pop. Density (per sq. mi.)           -0.028190       -0.066917
# Coastline (coast/area ratio)         -0.068199       -0.095627
# Net migration                         0.000011        0.047470
# Infant mortality (per 1000 births)    0.023003       -0.007163
# GDP ($ per capita)                   -0.039324        0.072185
# Literacy (%)                         -0.043481        0.035994
# Phones (per 1000)                    -0.030819        0.053403
# ...

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
sns.clustermap(corr_matrix)

# %%
print(df.isnull().sum())
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df[df['Agriculture'].isnull()]['Country']#output this comes when no missing values like no nan values
# Out:
# 3            American Samoa
# 4                   Andorra
# 78                Gibraltar
# 80                Greenland
# 83                     Guam
# 134                 Mayotte
# 140              Montserrat
# 144                   Nauru
# 153      N. Mariana Islands
# 171            Saint Helena
# 174    St Pierre & Miquelon
# 177              San Marino
# 208       Turks & Caicos Is
# 221       Wallis and Futuna
# 223          Western Sahara
# Name: Country, dtype: object

# %%
df[df['Agriculture'].isnull()]=df[df['Agriculture'].isnull()].fillna(0)

# %%
df['Agriculture']
# Out:
# 0      0.380
# 1      0.232
# 2      0.101
# 3      0.000
# 4      0.000
#        ...
# 222    0.090
# 223    0.000
# 224    0.135
# 225    0.220
# 226    0.179
# Name: Agriculture, Length: 227, dtype: float64

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                               18
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df['Climate']=df['Climate'].fillna(df.groupby('Region')['Climate'].transform("mean"))

# %%
print(df.isnull().sum())
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                                0
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df['Literacy (%)']=df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform("mean"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       226 non-null    float64
#  7   Infant mortality (per 1000 births)  226 non-null    float64
#  8   GDP ($ per capita)                  227 non-null    float64
#  9   Literacy (%)                        227 non-null    float64
#  10  Phones (per 1000)                   225 non-null    float64
# ...

# %%
update_df=df.dropna()

# %%
update_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             221 non-null    object
#  1   Region                              221 non-null    object
#  2   Population                          221 non-null    int64
#  3   Area (sq. mi.)                      221 non-null    int64
#  4   Pop. Density (per sq. mi.)          221 non-null    float64
#  5   Coastline (coast/area ratio)        221 non-null    float64
#  6   Net migration                       221 non-null    float64
#  7   Infant mortality (per 1000 births)  221 non-null    float64
#  8   GDP ($ per capita)                  221 non-null    float64
#  9   Literacy (%)                        221 non-null    float64
#  10  Phones (per 1000)                   221 non-null    float64
# ...

# %%
print(update_df.isnull().sum())
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
update_df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
X=df.drop('Country',axis=1)

# %%
X=pd.get_dummies(update_df)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X
# Out:
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# 4         71201             468                       152.1
# ..          ...             ...                         ...
# 222     2460492            5860                       419.9
# 223      273008          266000                         1.0
# 224    21456188          527970                        40.6
# 225    11502010          752614                        15.3
# 226    12236805          390580                        31.3
#
#      Coastline (coast/area ratio)  Net migration  \
# 0                            0.00          23.06
# 1                            1.26          -4.93
# 2                            0.04          -0.39
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_X=scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
ssd=[]
for k in range(2,30):
    model=KMeans(n_clusters=k)
    model.fit(scaled_X)
    ssd.append(model.inertia_)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning:
#
# ...

# %%
plt.plot(range(2,30),ssd,'o--')#bhai o-- is the way the graph is being displayed

# %%
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# CHOOSING K=3
# making a new model

# %%
model=KMeans(n_clusters=3)
model.fit(scaled_X)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
# KMeans(n_clusters=3)

# %%
X['K=3 Cluster Labels']=model.labels_

# %% [markdown]
# something wrong

# %%
X.corr()['K=3 Cluster Labels'].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# In general strong features for europe vs latin america nad oceania and stuff to see this gonna see colour codes on map

# %% [markdown]
# BONUS CHALLENGE

# %%
import plotly.express as px

# %%
isocodes=pd.read_csv('./country-iso-codes.csv')

# %%
iso_maps=isocodes.set_index('Country')['ISO Code'].to_dict()

# %%
update_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             221 non-null    object
#  1   Region                              221 non-null    object
#  2   Population                          221 non-null    int64
#  3   Area (sq. mi.)                      221 non-null    int64
#  4   Pop. Density (per sq. mi.)          221 non-null    float64
#  5   Coastline (coast/area ratio)        221 non-null    float64
#  6   Net migration                       221 non-null    float64
#  7   Infant mortality (per 1000 births)  221 non-null    float64
#  8   GDP ($ per capita)                  221 non-null    float64
#  9   Literacy (%)                        221 non-null    float64
#  10  Phones (per 1000)                   221 non-null    float64
# ...

# %%
update_df['ISO CODE']=update_df['Country'].map(iso_maps)
# Out:
# C:\Users\Taniya\AppData\Local\Temp\ipykernel_45508\2014086609.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
update_df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# now can see the last column is the iso code

# %%
update_df['Cluster']=model.labels_
# Out:
# C:\Users\Taniya\AppData\Local\Temp\ipykernel_45508\3527128495.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
update_df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
fig=px.choropleth(update_df,locations='ISO CODE',color='Cluster',hover_name='Country')
fig.show()
